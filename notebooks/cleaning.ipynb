# %% [markdown]
# Clean Alpaca CSV data

# %%
from pathlib import Path
from pipeline.alpaca import clean_market_data

raw_csv = Path('data') / 'AAPL_1Min_stock_alpaca_raw.csv'
clean_path = clean_market_data(raw_csv)

print('Clean:', clean_path)
